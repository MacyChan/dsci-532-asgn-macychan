# %%
import pandas as pd

# %%
dc_marvel = pd.read_csv('data/marvel_dc_characters.csv')
power_matrix = pd.read_csv('data/superheroes_power_matrix.csv')

# %%
all_charaters = pd.merge(
    dc_marvel,
    power_matrix,
    how="inner",
    on="Name")


all_charaters.to_csv( 'characters_processed.csv', index=False)

# %%
all_charaters.head()
# Out:
#         Name        Era Identity Alignment EyeColor HairColor Gender  \
# 0  Nightwing  New Earth   Secret       NaN     Blue       NaN   Male
# 1    Impulse  New Earth   Secret       Bad      NaN       NaN   Male
# 2    Impulse  Earth-616   Secret   Neutral      NaN        No   Male
# 3    Impulse  Earth-616   Secret   Neutral      NaN        No   Male
# 4    Impulse  Earth-616   Secret      Good      NaN       NaN   Male
#
#      Status  Appearances  FirstAppearance_Year  ...  Web Creation  \
# 0    Living          NaN                2010.0  ...         False
# 1    Living          1.0                2007.0  ...         False
# 2  Deceased         15.0                1977.0  ...         False
# 3  Deceased         15.0                1977.0  ...         False
# 4    Living          5.0                   NaN  ...         False
#
#    Reality Warping Odin Force Symbiote Costume Speed Force  Phoenix Force  \
# 0            False      False            False       False          False
# 1            False      False            False       False          False
# 2            False      False            False       False          False
# 3            False      False            False       False          False
# 4            False      False            False       False          False
#
#    Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 184 columns]
